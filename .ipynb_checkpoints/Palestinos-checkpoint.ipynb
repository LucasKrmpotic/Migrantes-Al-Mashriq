# %% [markdown]
# # Dataset Migrantes de Asia Sur Occidental - Al Mashriq
#
# + Revisando y concatenando archivos
# + Resolviendo NaN's
# + Aproximación a una descripción del Dataset

# %%
from IPython.display import Image

# %%
Image("img/mundo-arabe1.png", height="30%", width="30%")

# %%
Image("img/mundo-arabe2.jpg", height="40%", width="40%")

# %% [markdown]
# ### 1) Revisando y concatenando archivos

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
#df1 = pd.read_excel("ARABES.xlsx")
df2 = pd.read_excel("PRUEBA.xlsx")
df3 = pd.read_excel("PRUEBA1.xlsx")
df4 = pd.read_csv("Consulta.csv", sep=";")
df5 = pd.read_csv("Consulta2.csv", sep=";")
df6 = pd.read_csv("Consulta3.csv", sep=";")
df7 = pd.read_excel("PrimerArchivo(Hoja).xlsx")
df8 = pd.read_excel("SegundoArchivo(Hoja).xlsx")

# %% [markdown]
# <html><head>
#
#
# <!-- Load require.js. Delete this if your page already loads require.js -->
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.4/require.min.js" integrity="sha256-Ae2Vz/4ePdIu6ZyI/5ZGsYnb+m0JlOmKPjt6XZ9JJkA=" crossorigin="anonymous"></script>
# <script src="https://unpkg.com/@jupyter-widgets/html-manager@*/dist/embed-amd.js" crossorigin="anonymous"></script>
# <script type="application/vnd.jupyter.widget-state+json">
# {
#     "version_major": 2,
#     "version_minor": 0,
#     "state": {}
# }
# </script>
# </head>
# <body>
#
#
# </body>
# </html>

# %% [markdown]
#  * Cantidad de registros

# %%
print('Data frame 2: {} '.format(len(df2)))
print('Data frame 3: {} '.format(len(df3)))
print('Data frame 4: {} '.format(len(df4)))
print('Data frame 5: {} '.format(len(df5)))
print('Data frame 6: {} '.format(len(df6)))
print('Data frame 7: {} '.format(len(df7)))
print('Data frame 8: {} '.format(len(df8)))
print('===================')
print('    Total: {}'.format(len(df2) + len(df3) + len(df4) + len(df5) + len(df6) + len(df7) + len(df8)))
print('===================')
# Out:
# Data frame 2: 45296
# Data frame 3: 9346
# Data frame 4: 9346
# Data frame 5: 9346
# Data frame 6: 9346
# Data frame 7: 13815
# Data frame 8: 85816
# ...
#     Total: 182311
# ...

# %% [markdown]
# Revisamos heads y tails para verificar si los df 3, 4, 5, y 6 contienen los mismos datos

# %%
# Los primeros 5 registros 

#df3.head()
#df4.head()
#df5.head() #Este tiene un formato defectuoso
df6.head()

# Los últimos 5 registros

#df3.tail()
#df4.tail()
df6.tail()
# Out:
#             NOMBRE VAPOR        APELLI         NOMBRE  NACION   PUERTO_descri  \
# 9341            PROVENCE    ELIAS NAZU           ALIC    1556        MARSELLA
# 9342  HIGHLAND CHIEFTAIN       REICHER         ALIOJA     126          SANTOS
# 9343  HIGHLAND CHIEFTAIN       REICHER  SHOSHANA HANA     126          SANTOS
# 9344  HIGHLAND CHIEFTAIN       RACIMOR         JEHUDA     126  RIO DE JANEIRO
# 9345          CORRIENTES  NASIF MADAIN         HAKAWE    1556         NAPOLES
#
#       EDAD SEXO ESTCIV RELIGI_descri INSTRU               FECLLE       PROFES  \
# 9341  24.0    F      S      CATOLICA      S   4/12/1956 00:00:00      LABORES
# 9342  38.0    F      C      CATOLICA      S    3/1/1958 00:00:00  P.DOMESTICA
# 9343   7.0    F      S      CATOLICA      S    3/1/1958 00:00:00      ESTUDIA
# 9344  30.0    M      S         JUDIA      S    3/1/1958 00:00:00   AGRICULTOR
# 9345  49.0    M      C      CATOLICA      S  18/12/1956 00:00:00  COMERCIANTE
#
# ...

# %% [markdown]
# Los archivos:
# + PRUEBA1.xlsx
# + Consulta.csv
# + Consulta2.csv
# + Consulta3.csv
#
# contienen los mismos datos.
# Por otro lado el archivo consulta2.csv está en un formato defectuoso
#
# Nos quedamos con el archivo PRUEBA1.xlsx para armar el Dataset

# %% [markdown]
# Revisamos nuevamente cantidad de registros, y total.

# %%
print('Data frame 2: {} '.format(len(df2)))
print('Data frame 3: {} '.format(len(df3)))

print('Data frame 7: {} '.format(len(df7)))
print('Data frame 8: {} '.format(len(df8)))
print('===================')
print('    Total: {}'.format(len(df2) + len(df3) + len(df7) + len(df8)))
print('===================')
# Out:
# Data frame 2: 45296
# Data frame 3: 9346
# Data frame 7: 13815
# Data frame 8: 85816
# ...
#     Total: 154273
# ...

# %% [markdown]
# * Concatenación de archivos

# %%
frames = [df2, df3, df7, df8]
result = pd.concat(frames)
